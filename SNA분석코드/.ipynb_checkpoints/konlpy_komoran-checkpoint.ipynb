# %%
import re
import pandas as pd
import numpy as np
import konlpy

# %%
Okt =  konlpy.tag.Okt()
p = re.compile("[^0-9]")

# %%
## 명사/동사/형용사 뽑기
clean_words = []
for word in Okt.pos(data[',context,comment'][0], stem=True): #어간 추출
    if word[1] in ['Noun', 'Verb', 'Adjective']: #명사, 동사, 형용사
        clean_words.append(word[0])
document = ','.join(clean_words)
# Out:
# ['국내', '주행', '중인', '해외', '차', '차량', '얘기', '보다', '보다', '문득', '생각나다']

# %%
data2 = pd.read_csv("clien_data_v2.csv", encoding='utf-8-sig',sep='\t')
data2 = data2[~data2['total'].isnull()].reset_index()
data2['total'] = data2['total'].apply(lambda x: "".join(p.findall(str(x))))

# %%
data = pd.read_csv("sna_lpg_pole_v2.csv",sep='\t,',encoding='utf-8')
data[',context,comment'] = data[',context,comment'].apply(lambda x: "".join(p.findall(str(x))))
# Out:
# c:\users\ina lee\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
data3 = pd.read_csv("youtube_crawling_LPG.csv")
data3 = data3[~data3['ko_reply'].isnull()].reset_index()

# %%
data3['ko_reply']
# Out:
#       index  Unnamed: 0  like  \
# 0         0           0  38.0
# 1         1           1  14.0
# 2         2           2  11.0
# 3         3           3   2.0
# 4         4           4   2.0
# 5         5           5   7.0
# 6         6           6   1.0
# 7         7           7   5.0
# 8         8           8   3.0
# 9         9           9  13.0
# 10       10          10   8.0
# 11       11          11   1.0
# 12       12          12   NaN
# 13       13          13   1.0
# 14       14          14   4.0
# 15       15          15   1.0
# 16       16          16  13.0
# 17       17          17   1.0
# 18       18          18   3.0
# 19       19          19   1.0
# 20       20          20  21.0
# 21       21          21   5.0
# 22       22          22   3.0
# 23       23          23   2.0
# 24       24          24   8.0
# 25       25          25   5.0
# 26       26          26   2.0
# 27       27          27  10.0
# 28       28          28   5.0
# 29       29          29   2.0
# ...     ...         ...   ...
# 1194   1205        1205   3.0
# 1195   1206        1206   2.0
# 1196   1207        1207   NaN
# 1197   1208        1208   NaN
# 1198   1209        1209   3.0
# 1199   1210        1210   3.0
# 1200   1211        1211   3.0
# 1201   1212        1212   1.0
# 1202   1213        1213   NaN
# 1203   1214        1214   NaN
# 1204   1215        1215   NaN
# 1205   1216        1216   1.0
# 1206   1217        1217   1.0
# 1207   1218        1218   1.0
# 1208   1219        1219   NaN
# 1209   1220        1220   NaN
# 1210   1221        1221   1.0
# 1211   1222        1222   3.0
# 1212   1223        1223   NaN
# 1213   1224        1224   NaN
# 1214   1225        1225   1.0
# 1215   1226        1226   2.0
# 1216   1227        1227   NaN
# 1217   1228        1228   1.0
# 1218   1229        1229   NaN
# 1219   1230        1230   NaN
# 1220   1231        1231   NaN
# 1221   1232        1232   NaN
# 1222   1233        1233   1.0
# 1223   1234        1234   3.0
#
#                                                ko_title  \
# 0                                     년안된 더뉴스파크중고차가 이가격
# 1                                     년안된 더뉴스파크중고차가 이가격
# 2                                     년안된 더뉴스파크중고차가 이가격
# 3                                     년안된 더뉴스파크중고차가 이가격
# 4                                     년안된 더뉴스파크중고차가 이가격
# 5                                     년안된 더뉴스파크중고차가 이가격
# 6                                     년안된 더뉴스파크중고차가 이가격
# 7                                     년안된 더뉴스파크중고차가 이가격
# 8                                     년안된 더뉴스파크중고차가 이가격
# 9                                     년안된 더뉴스파크중고차가 이가격
# 10                                    년안된 더뉴스파크중고차가 이가격
# 11                                    년안된 더뉴스파크중고차가 이가격
# 12                                    년안된 더뉴스파크중고차가 이가격
# 13                                    년안된 더뉴스파크중고차가 이가격
# 14                                    년안된 더뉴스파크중고차가 이가격
# 15                                    년안된 더뉴스파크중고차가 이가격
# 16                                    년안된 더뉴스파크중고차가 이가격
# 17                                    년안된 더뉴스파크중고차가 이가격
# 18                                    년안된 더뉴스파크중고차가 이가격
# 19                                    년안된 더뉴스파크중고차가 이가격
# 20                         차 구매 이런분들은 금지 가스차말고 휘발유차 타세요
# 21                         차 구매 이런분들은 금지 가스차말고 휘발유차 타세요
# 22                         차 구매 이런분들은 금지 가스차말고 휘발유차 타세요
# 23                         차 구매 이런분들은 금지 가스차말고 휘발유차 타세요
# 24                         차 구매 이런분들은 금지 가스차말고 휘발유차 타세요
# 25                         차 구매 이런분들은 금지 가스차말고 휘발유차 타세요
# 26                         차 구매 이런분들은 금지 가스차말고 휘발유차 타세요
# 27                         차 구매 이런분들은 금지 가스차말고 휘발유차 타세요
# 28                         차 구매 이런분들은 금지 가스차말고 휘발유차 타세요
# 29                         차 구매 이런분들은 금지 가스차말고 휘발유차 타세요
# ...                                                 ...
# 1194                               세종서  차 사고 후 화재명 사망
# 1195                               세종서  차 사고 후 화재명 사망
# 1196                               세종서  차 사고 후 화재명 사망
# 1197                               세종서  차 사고 후 화재명 사망
# 1198           엔진오일 추천하기  차량 오너님들 들어오세요 훅스타이탄 모튤엔진오일 추천
# 1199           엔진오일 추천하기  차량 오너님들 들어오세요 훅스타이탄 모튤엔진오일 추천
# 1200           엔진오일 추천하기  차량 오너님들 들어오세요 훅스타이탄 모튤엔진오일 추천
# 1201           엔진오일 추천하기  차량 오너님들 들어오세요 훅스타이탄 모튤엔진오일 추천
# 1202  그랜드카니발정부지원금노후경유차교체지원학원차량변경어떤차가올까곧 교회차되어 다행동탄영광...
# 1203  그랜드카니발정부지원금노후경유차교체지원학원차량변경어떤차가올까곧 교회차되어 다행동탄영광...
# 1204  그랜드카니발정부지원금노후경유차교체지원학원차량변경어떤차가올까곧 교회차되어 다행동탄영광...
# 1205    올란도 와 모닝 휘발유 주유비는 어떤게 더 저렴할까 가스차 연비 휘발유차와 비교 영상
# 1206    올란도 와 모닝 휘발유 주유비는 어떤게 더 저렴할까 가스차 연비 휘발유차와 비교 영상
# 1207                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1208                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1209                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1210                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1211                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1212                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1213                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1214                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1215                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1216                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1217                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1218                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1219                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1220                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1221                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1222                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
# 1223                    쌍용 티볼리 개조  티볼리 오너들에게 최고의 축복인 이유
#
#                                                ko_reply
# 0                                                 믿거엠파크
# 1                                          경차 최대단점 시끄러움
# 2                                    연비 떠나서 체감 엄청 피곤함ㅋㅋ
# 3                                            항상 잘보고있습니다
# 4                                             인천  그 지역
# 5                                        근데 왜 자리번호판아니에요
# 6                                            뭐야 옵션 왜캐좋아
# 7                     전방감지기ㅋㅋㅋㅋ에효저거 후측방 추돌방지 감지센서 입니다ㅜㅜ
# 8     간석매매단지네요 여년전에 저희 아버지가 처음에 레조 가스차 뽑으셨을때 옆에 홈플러스...
# 9                          출퇴근용인데 풀옵션은 과하죠 ㅎ여유가 된다면 뭐 ㅎ
# 10                        김팀장님도 현실적인 중고차 컨설팅을 해드립니다 여러분
# 11                                       폰이 두분이 커플이세요ㅎㅎ
# 12                                             대차도 되는가요
# 13                                              차 이쁘긴하다
# 14    김팀장님 정말 노력하고 계신모습 너무 좋습니다 노력하는 만큼 사람들이 알아주지 못해...
# 15                                   왜이렇게 두분 다 어색하십니까ㅎㅎ
# 16    경차는 꾹 밟으면 안대요 지긋이 누르듯 해야하고 꾹 밟아봐야 알피엠만 올라가고 기름...
# 17                      오래살고 싶으면 스파크 타시고 가성비 따지면 모닝 타세요
# 18             삼성은 진짜 잔고장이없는것같음뉴임프레션 년째 타고다니는데배터리간것밖에없음
# 19    만원 아래로 살 수있는 넥스트스파크 거의 풀옵으로 있을까요 사고있어도 큰사고 아니고...
# 20    잘못된 정보 주의하세요시내주행만해도 가스차가 훨씬 저렴합니다장거리만 가스차가 저렴하...
# 21    동급디젤과 동급가솔린으로 비교하면 령상에서하시는말씀 다 맞습니다 ㅎㅎㅎ 댓글들 무식...
# 22    요즘나온 디젤 차들은 전보단 안나가는거 같습니다아무래도   요소수 방식이 들어가고 ...
# 23    와 저도 차 생각중인데 찾아보니 출퇴근 구간에 딱하나 있네요 ㄷㄷㄷ없었으면 삥 돌아...
# 24                                             출력 괜춘합니다
# 25    디젤  둘다 소유중  차 안나간다는말은 안타본사람들이 하는말입니다 디젤토크 무시못하...
# 26                                         늘 풀 악셀 하나 ㅋㅋ
# 27          리터당 연비 따지지 말고 당 몇 원 인가릇 따지면 가스차를 안탈 이유가 없지요
# 28                                             차에대해 도모름
# 29               제목을 자극적으로 금지라고 할게 아니라 고려라고 고쳐야 하지 않을까요
# ...                                                 ...
# 1194                                      삼가고인의 명복을 빕니다
# 1195                                       고인들의 명복을 빕니다
# 1196                        참으로 안타까운 사고입니다삼가 고인의명복을 빕니다
# 1197  박근혜 대 통령 건강하 시고 그안에서 기도많이 하세요 찬송 과 말씀 을많이 보세요 ...
# 1198                                     도  도 추천해주세요 ㅠㅠ
# 1199            훅스는   제품은 못찾겠어요  와  는 있던데요 판매하시는 제품 맞나요
# 1200          해주시는김에  디젤 모델은 따로 추천 안해주실까요 종류가 많이 없겠지만요ㅠ
# 1201                       프리미어  입니다 오일 뭐가 좋을까요더 고민만 ㅋㅋ
# 1202                                   년형 그랜드스타렉스 년식이에요
# 1203                                        말소하면 지원안되나요
# 1204                                              재매섯서요
# 1205   겨울이라 가스차 연비가 여름보다 조금 떨어지는데 여름엔 얼마나 더 차이가날지 기대됩니다
# 1206  맞습니다 가 훨씬 실용적고 이득이 많습니다 아무리 경차라도수동 이던  연비랑 기름값...
# 1207  픽업트럭에 적용하면  비포장 도로로 거의 사용하지 않은 특성을 감안한다면경제적인 이...
# 1208                        요즘 나오는 신형 코란도에도 적용 가능한가요 ㅠㅠ
# 1209                        년산 렉스턴도 로 바꿀수 있는지요답글 부탁드릴게요
# 1210                       중고 현대 기아 가솔린차는 연식 상관없이 가능한가요
# 1211                                 튜닝 가능한 차량이 어떻게 되나요
# 1212                                        포드에 장착가능한가요
# 1213                                      출력 그래프도 보여주세요
# 1214                      차내부 찍을 때는 라이트를 켜야할듯요어두워 잘 안보임
# 1215                         쏘울 부스터는 경차가 아닌데 장착이 안되는건가요
# 1216  티볼리에어소형이아니고중형으로들어가더만 내차티볼리에어디젤 인데  등록증에 중형이라적혀잇는데
# 1217  코란도스포츠 휘발유도 엔진인데 개조가 가능한가요 리터당 연비는 휘발유에 비해 어느정...
# 1218                                  이게 일반 가솔린차도 교체가되요
# 1219                            베리뉴 티볼리 가솔린모델도 튜닝 가능한가요
# 1220                                          경차는 아직일까요
# 1221      바로 전 영상 댓글로 문의드렸는데 싼타페랑 같은  세타 터보인데 벨엔도 가능한가요
# 1222  장착은 간단해보이는데 가격은 어느정도인가요 충전구멍은 어느쪽으로 사용할 수 있는건가...
# 1223  앞전에 남자 직원분 목소리가 좋던데ㅎㅎ같은 남자인데도 설명하기에 부드러운 목소리든데...
#
# [1224 rows x 5 columns]

# %%
def my_stopwords():
    s_file = open('stopwords_kr.txt', 'r', encoding='utf-8')
    stop_list = s_file.readlines()

    my_stopwords = []
    for s_word in stop_list:
        my_stopwords.append(s_word.strip())
    return my_stopwords

my_stopwords = my_stopwords()
komoran =  konlpy.tag.Komoran()
output = open("LPG_CAR_NOUN.txt", 'w', encoding='utf-8')

for line in range(len(data2)):
    #cn = data2['Unnamed: 0'][line]
    #output.write('{}\t'.format(cn))
    try:
        clean_words = []
        for word in Okt.pos(data2['total'][line], stem=True): #어간 추출
            if word[1] in ['Noun','Alpha']: #명사, 영어, 형용사
                clean_words.append(word[0])
        #print(clean_words)
        document = ','.join(clean_words)
        #word_nouns = komoran.nouns(data[',context,comment'][line])      # 명사추출
        for wn in clean_words:
            if wn not in my_stopwords:
                output.write('%s ' % wn)
        output.write('\n')

    except UnicodeDecodeError:
        pass

print("finished")

output.close()

# %%
# Count cooccurences
# input: nlp_file
# output: cooc_frq.txt, cooc_frq.graphml

# 하나의 네트워크 파일 만드는 수식 (동시출현)


import operator
#from cooc.my_graphml import MakeGraphml

def search_vocab(word):
    if w_dict.get(word):
        tid = w_dict.get(word)
        #print(word)
    else:
        w_dict[word] = len(w_dict) + 1  # {term: tid} 추가 
        tid = w_dict.get(word)
        t_dict[tid] = word          # {tid: term} 추가
    return tid


def count_cooc(aid, bid):
    if count.get((aid, bid)):
        count[aid,bid] = count[aid,bid] + 1
    else:
        count[aid,bid] = count[aid,bid] = 1
    #print(aid, bid, count[aid,bid])
    

''' main function '''
# input
input_file = 'LPG_CAR_NOUN.txt'  ##형태소 분석 해줬던 파일 
# output: pair file
pair_file = 'cooc_LPG_CAR_NOUN.txt'
# frq_threshold
thres = 100

f = open(input_file, 'r', encoding='utf-8')
out = open(pair_file, 'w', encoding='utf-8')

w_dict = {}   # dic {term: tid}
t_dict = {}   # dic {tid: term}
count = {}   # dic {(a,b):frq}

line = 0
for text in f.readlines():
    words = text.split('\t')[0].strip().split()   # 단어가 들어있는 칼럼[1]. 한줄씩 읽어와서 단어별로 분리
    line += 1
    #print(line)

    for i, a in enumerate(words):
        #print(i, a)
        aid = search_vocab(a)            # check tid
        
        for b in words[i+1:]:
            bid = search_vocab(b)        # check tid
            
            if aid == bid: continue     # 동일단어 pass
            elif aid < bid:
                count_cooc(aid, bid)
            else:                       # when a > b, 자리바꿈
                count_cooc(bid, aid)

    #break

#print(w_dict)
#print(t_dict)

# itemgetter(0): key 또는 itemgetter(1): value로 sort key, reverse=True (descending order)
sorted_value = sorted(count.items(), key=operator.itemgetter(1), reverse=True)
for i in range(len(sorted_value)):
    if sorted_value[i][1] >= thres:
        #print(sorted_value[i])
        print(t_dict[sorted_value[i][0][0]], t_dict[sorted_value[i][0][1]], sorted_value[i][1])
        out.write('{}\t{}\t{}\n'.format(t_dict[sorted_value[i][0][0]], t_dict[sorted_value[i][0][1]], sorted_value[i][1]))

print("===== Done =====")
f.close()
out.close()

# %%
# my_graphml.py
# option: graphml file
# gephi 네트워크 만들어주기


pair_file = 'cooc_LPG_CAR_NOUN.txt'
graphml_file = 'cooc_LPG_CAR_NOUN.graphml'

pairs = open(pair_file, 'r', encoding = 'utf-8')
out = open(graphml_file, 'w', encoding = 'utf-8')

entity = []
e_dict = {}
count = []
for pair in pairs.readlines():
    e1 = pair.split('\t')[0]
    e2 = pair.split('\t')[1]
    #frq = ((word_dict[e1], word_dict[e2]),  pair.split('\t')[2])
    frq = ((e1, e2), pair.split('\t')[2])
    if frq not in count: count.append(frq)   # ((a, b), frq)
    if e1 not in entity: entity.append(e1)
    if e2 not in entity: entity.append(e2)
print('# terms: %s'% len(entity))

#create e_dict {entity: id} from entity
for i, w in enumerate(entity):
    e_dict[w] = i + 1 # {word: id}

out.write(
    "<?xml version=\"1.0\" encoding=\"UTF-8\"?><graphml xmlns=\"http://graphml.graphdrawing.org/xmlns\" xmlns:xsi=\"http://www.w3.org/2001/XMLSchema-instance\" xsi:schemaLocation=\"http://graphml.graphdrawing.org/xmlnshttp://graphml.graphdrawing.org/xmlns/1.0/graphml.xsd\">" +
    "<key id=\"d1\" for=\"edge\" attr.name=\"weight\" attr.type=\"double\"/>" +
    "<key id=\"d0\" for=\"node\" attr.name=\"label\" attr.type=\"string\"/>" +
    "<graph id=\"Entity\" edgedefault=\"undirected\">" + "\n")

# nodes
for i in entity:
    out.write("<node id=\"" + str(e_dict[i]) +"\">" + "\n")
    out.write("<data key=\"d0\">" + i + "</data>" + "\n")
    out.write("</node>")

# edges
for y in range(len(count)):
    out.write("<edge source=\"" + str(e_dict[count[y][0][0]]) + "\" target=\"" + str(e_dict[count[y][0][1]]) + "\">" + "\n")
    out.write("<data key=\"d1\">" + str(count[y][1]) + "</data>" + "\n")

    #out.write("<edge source=\"" + str(count[y][0][0]) + "\" target=\"" + str(count[y][0][1]) +"\">"+"\n")
    #out.write("<data key=\"d1\">" + str(count[y][1]) +"</data>"+"\n")
    out.write("</edge>")

out.write("</graph> </graphml>")
print('now you can see %s' % graphml_file)

pairs.close()
out.close()

# 1264 -> node가 1264개란 의미....
# Out:
# # terms: 2633
# now you can see cooc_LPG_YOUTUBE_NOUN.graphml
